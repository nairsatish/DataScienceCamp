# %% [markdown]
# <a href="https://colab.research.google.com/github/nairsatish/DataScienceCamp/blob/main/Data_Science_Camp_Getting_Started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Access Canvas Page for the Camp**
#
# All information and materials for the course will be accessible from the course Canvas page.
#
# The login page for Canvas is at this site: [Canvas Login](https://canvas.umsystem.edu/)
#
# 1. Follow the instructions on this page for creating a Canvas account: [Creating a Canvas Account for UMSystem](https://teachingtools.umsystem.edu/support/solutions/articles/11000111782-creating-a-cirrus-identity-canvas-account)
# 2. After creating an account, send an email to **medcurriculumMizzou@gmail.com** providing the **email address** used to create the account.
# 3. Once the email is sent, you will be invited to the Canvas Page.
# 4. You will receive an invitation email with a link labeled **GET STARTED**. Click GET STARTED to gain access to the course.

# %% [markdown]
# ## **TO DO PRIOR TO THE CAMP**
#
# 1.. Complete the Activity listed at the Canvas site under Fear Lesson Plans - 'TO DO PRIOR TO COMING TO THE FIRST SESSION" and bring the activity sketch to class
#
# 2.. About the items below in this file:
#
# (a). Get familiar with Google Colab (required)
#
# (b). If you have time, explore GitHub (optional)
#
# (c). Get an account to access the YouCubed course (required)
#
# (d). Get an account to access the Stanford course as indicated below (recommended)

# %% [markdown]
# ## **Google Colab**
#
# **Google Colaboratory (Colab)** is a free tool from Google for writing and executing Python code in the browser.
# <br>
# Colab also provides the ability to add text, images, and links, making it a great tool for creating learning material.
# <br>
#
# ### **Colab - FAQ**: https://research.google.com/colaboratory/faq.html

# %%
#@title **Colab - Tutorial for Beginners**

from IPython.display import YouTubeVideo
YouTubeVideo('iMlMfrXJYSg')

# %%
#@title **Try Running Some Code!**

# Click the play button to run this cell of code!

import random

while (True):
  try:
    guess = int(input('Guess a number 1-10: '))
    break
  except:
    print('Make sure your guess is a whole number!')
    continue

number = random.randint(1, 10)

if (guess == number):
  print('You guessed it!')
else:
  print(f'Sorry, the number was {number}!')

# %% [markdown]
# ## **GitHub**
#
# **GitHub** is a web-based service to share code, store and manage it, and track code revisions.
#
# ### **What is GitHub?**: https://kinsta.com/knowledgebase/what-is-github/
#
# ### **GitHub Basics**: https://docs.github.com/en/get-started/quickstart/hello-world
#
# We will use GitHub to access tutorials and materials, so create a GitHub account if you don't have one at https://github.com/

# %% [markdown]
# ## **YouCubed**
#
# YouCubed is a great resource for educational materials for math and data science.
# <br>
# We will be using parts of their curriculum, "Explorations in Data Science", to learn about the fundamentals of data science.
#
# The material is free, so to access it you just need to create a YouCubed account.
#
# [Register - YouCubed](https://hsdatascience.youcubed.org/register/)

# %% [markdown]
# ## **Stanford Course - Machine Learning**
#
# For the machine learning component of the course, we will be used the Stanford COURSERA course "Machine Learning".
# <br>
# To begin, first enroll in the free Stanford course using the site below and then ***watch the videos for Week 1*** at the course site
# 1. Click **Enroll for Free**
# 2. **Sign up** for an account and sign in or click **Continue with Google** to use your Google account
# 3. A prompt will pop up saying "7-Day Free Trial", click **Audit** at the bottom for the free version of the course.
#
# [Stanford Course - Machine Learning](https://www.coursera.org/learn/machine-learning)
